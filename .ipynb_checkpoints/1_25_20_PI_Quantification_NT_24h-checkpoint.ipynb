# %%
import os
import os.path as op
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import skimage.io
import skimage.filters
from skimage.filters import try_all_threshold
import matplotlib.image as mpimg
from scipy import ndimage as ndi
from skimage.transform import resize
import skimage.morphology
import skimage.feature
import math
from math import sqrt
from skimage.color import rgb2gray
from skimage import measure
from skimage import data, util

# %%
prefix = ['NT_24h_PI_']
regions = ['corpus_callosum', 'cortex', 'striatum']
images = 5

image_list = []
for pref in prefix:
    for region in regions:
        for num in range(1,images+1):
            image_list.append('{}{}_20x_images_XY{}.tif'.format(pref,region,num))

# %%
image_list
# Out:
# ['NT_24h_PI_corpus_callosum_20x_images_XY1.tif',
#  'NT_24h_PI_corpus_callosum_20x_images_XY2.tif',
#  'NT_24h_PI_corpus_callosum_20x_images_XY3.tif',
#  'NT_24h_PI_corpus_callosum_20x_images_XY4.tif',
#  'NT_24h_PI_corpus_callosum_20x_images_XY5.tif',
#  'NT_24h_PI_cortex_20x_images_XY1.tif',
#  'NT_24h_PI_cortex_20x_images_XY2.tif',
#  'NT_24h_PI_cortex_20x_images_XY3.tif',
#  'NT_24h_PI_cortex_20x_images_XY4.tif',
#  'NT_24h_PI_cortex_20x_images_XY5.tif',
#  'NT_24h_PI_striatum_20x_images_XY1.tif',
#  'NT_24h_PI_striatum_20x_images_XY2.tif',
#  'NT_24h_PI_striatum_20x_images_XY3.tif',
#  'NT_24h_PI_striatum_20x_images_XY4.tif',
#  'NT_24h_PI_striatum_20x_images_XY5.tif']

# %%
output_data = pd.DataFrame(columns=['Image', 'DAPI count','DAPI intensity', 'DAPI area', 'PI count', 'PI intensity', 'PI area', 'PI intensity/DAPI count', 'PI w/in DAPI area', 'PI w/in DAPI/DAPI count', '%overlap PI/DAPI'])

# %%
output_data
# Out:
# Empty DataFrame
# Columns: [Image, DAPI count, DAPI intensity, DAPI area, PI count, PI intensity, PI area, PI intensity/DAPI count, PI w/in DAPI area, PI w/in DAPI/DAPI count, %overlap PI/DAPI]
# Index: []

# %%
for image in image_list:
    img = skimage.io.imread('./drive-download-20200212T210242Z-001/'+image)
    DAPI = img[0]
    PI = img[1]
    DAPI_filtered = ndi.gaussian_filter(DAPI, sigma=1)
    PI_filtered = ndi.gaussian_filter(PI, sigma=1)
    DAPI_thresh = skimage.filters.threshold_otsu(DAPI_filtered)
    DAPI_binary = DAPI_filtered > DAPI_thresh
    PI_thresh = skimage.filters.threshold_otsu(PI_filtered)
    PI_binary = PI_filtered > PI_thresh
    DAPI_dilation = skimage.morphology.binary_dilation(DAPI_binary)
    DAPI_filled_holes = ndi.binary_fill_holes(DAPI_dilation)
    DAPI_clean = skimage.morphology.remove_small_objects(DAPI_filled_holes, min_size=30)
    PI_dilation = skimage.morphology.binary_dilation(PI_binary)
    PI_filled_holes = ndi.binary_fill_holes(PI_dilation)
    PI_clean = skimage.morphology.remove_small_objects(PI_filled_holes, min_size=30)
    labeled_DAPI, _ = ndi.label(DAPI_clean)
    labeled_PI, _ = ndi.label(PI_clean)
    PI_props = measure.regionprops(labeled_PI)
    DAPI_props = measure.regionprops(labeled_DAPI)
    
    props_DAPI = pd.DataFrame(columns=['centroid x', 'centroid y', 'filled_area', 'area'])

    k = 1
    for props in DAPI_props:
    #Get the properties that I need for areas
    #Add them into a pandas dataframe that has the same number of rows as objects detected
        centroid = props.centroid
        centroid_x = centroid[0]
        centroid_y = centroid[1]
        fill_area = props.filled_area
        area = props.area
        props_DAPI.loc[k] = [centroid_x, centroid_y, fill_area, area]
        k = k + 1
        

    props_PI = pd.DataFrame(columns=['centroid x', 'centroid y', 'filled_area', 'area'])

    j = 1
    for props in PI_props:
    #Get the properties that I need for areas
    #Add them into a pandas dataframe that has the same number of rows as objects detected
        centroid = props.centroid
        centroid_x = centroid[0]
        centroid_y = centroid[1]
        fill_area = props.filled_area
        area = props.area
        props_PI.loc[j] = [centroid_x, centroid_y, fill_area, area]
        j = j + 1
    
    PI_overlap_sum = 0
    DAPI_pixels = 0
    i = 0
    PI_pixels = 0

    for ydim in range(0,512):
        for xdim in range(0,512):
            if labeled_DAPI[ydim][xdim] != 0:
                PI_overlap_sum = PI_overlap_sum + PI[ydim][xdim]
                DAPI_pixels = DAPI_pixels+1
                i = i + 1
                if labeled_PI[ydim][xdim] != 0:
                    PI_pixels = PI_pixels + 1
    
    output_data = output_data.append({'Image':image, 'DAPI count':len(props_DAPI), 'PI count':len(props_PI), 'DAPI intensity':DAPI.sum(), 'PI intensity':PI.sum(), 'DAPI area':props_DAPI['area'].sum(), 'PI area':props_PI['area'].sum(), 'PI intensity/DAPI count':PI.sum()/len(props_DAPI), 'PI w/in DAPI area':PI_overlap_sum, 'PI w/in DAPI/DAPI count':PI_overlap_sum/len(props_DAPI), '%overlap PI/DAPI':PI_pixels/DAPI_pixels}, ignore_index=True)

# %%
output_data
# Out:
#                                            Image DAPI count DAPI intensity  \
# 0   NT_24h_PI_corpus_callosum_20x_images_XY1.tif        237       38245169
# 1   NT_24h_PI_corpus_callosum_20x_images_XY2.tif        242       21756232
# 2   NT_24h_PI_corpus_callosum_20x_images_XY3.tif        260       25954980
# 3   NT_24h_PI_corpus_callosum_20x_images_XY4.tif        231       22890215
# 4   NT_24h_PI_corpus_callosum_20x_images_XY5.tif        247       31479176
# 5            NT_24h_PI_cortex_20x_images_XY1.tif        270       23105457
# 6            NT_24h_PI_cortex_20x_images_XY2.tif        376       64390061
# 7            NT_24h_PI_cortex_20x_images_XY3.tif        315       48084318
# 8            NT_24h_PI_cortex_20x_images_XY4.tif        258       26877602
# 9            NT_24h_PI_cortex_20x_images_XY5.tif        239       28248368
# 10         NT_24h_PI_striatum_20x_images_XY1.tif        295       52711357
# 11         NT_24h_PI_striatum_20x_images_XY2.tif        254       43895005
# 12         NT_24h_PI_striatum_20x_images_XY3.tif        284       48338289
# 13         NT_24h_PI_striatum_20x_images_XY4.tif        269       50563524
# 14         NT_24h_PI_striatum_20x_images_XY5.tif        232       48288405
#
#     DAPI area PI count PI intensity  PI area  PI intensity/DAPI count  \
# 0     13954.0      271      4858160  17241.0             20498.565401
# 1     20841.0      215      2724319  17616.0             11257.516529
# 2     22518.0      232      3210040  20483.0             12346.307692
# 3     16362.0      217      2904721  15192.0             12574.549784
# 4     18187.0      235      3912679  19472.0             15840.805668
# 5     16344.0      216      2579411  13533.0              9553.374074
# 6     22533.0      381      9344103  24481.0             24851.337766
# 7     18592.0      325      7019779  18708.0             22285.012698
# 8     14644.0      244      4206963  14714.0             16306.058140
# 9     13218.0      233      4143708  13956.0             17337.690377
# 10    16857.0      356      8308280  28142.0             28163.661017
# 11    15151.0      323      7244802  26378.0             28522.842520
# 12    16864.0      321      8951629  26163.0             31519.820423
# 13    15312.0      300      9222741  22509.0             34285.282528
# 14    13676.0      278      7832829  20790.0             33762.193966
#
#    PI w/in DAPI area  PI w/in DAPI/DAPI count  %overlap PI/DAPI
# 0             995753              4201.489451          0.906335
# 1             651022              2690.173554          0.740272
# 2             929439              3574.765385          0.802780
# 3             645088              2792.588745          0.781750
# 4             957539              3876.676113          0.888877
# 5             421723              1561.937037          0.680617
# 6            1773293              4716.204787          0.855856
# 7            1216854              3863.028571          0.834552
# 8             558321              2164.034884          0.735387
# 9             514831              2154.104603          0.745499
# 10           1438419              4875.996610          0.898143
# 11           1198844              4719.858268          0.880272
# 12           1631335              5744.137324          0.904471
# 13           1578844              5869.308550          0.923524
# 14           1272976              5486.965517          0.932802

# %%
output_data.to_csv('1_25_20_NT_24h_PI_quantification.csv', encoding='utf-8', index=False)
