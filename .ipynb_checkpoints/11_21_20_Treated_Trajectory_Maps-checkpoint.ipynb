# %%
import os
import os.path as op
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy.ma as ma
#from scipy import stats

# %% [markdown]
# ## Trajectory maps

# %%
#path = '~/Desktop/MPT_Data/Trajectory_Maps/'

NT_filename = 'msd_ChABC_brain_1_slice_3_vid_4'


merged = pd.read_csv(NT_filename+'.csv')
particles = int(max(merged['Track_ID']))
ires = 512
figsize = (5,5)
cols = 4
rows = 4

fig = plt.figure(figsize=figsize, dpi=300)
for part in range(0, particles):
    x = merged[merged['Track_ID'] == part]['X']*0.07
    y = merged[merged['Track_ID'] == part]['Y']*0.07
    plt.plot(x, y, alpha=1, color = 'goldenrod')

plt.xlim(0, ires*4*0.07)
plt.ylim(0, ires*4*0.07)
plt.tick_params(axis='both', which='major', labelsize=18, length=6, width=2)
plt.xticks(np.arange(0,151,25))
plt.yticks(np.arange(0,151,25))
plt.ylabel('distance ('r'$\mu$m)', fontsize=20, weight='bold')
plt.xlabel('distance ('r'$\mu$m)', fontsize=20, weight='bold')
plt.show()

# %%
merged[0:5]
# Out:
#    Unnamed: 0  Frame  Track_ID           X            Y       MSDs     Gauss  \
# 0           0    0.0       0.0  315.208842  1561.008011   0.000000  0.000000
# 1           1    1.0       0.0  300.777663  1553.290366  34.934064  1.842153
# 2           2    2.0       0.0  299.503058  1549.518655  50.289614  1.596229
# 3           3    3.0       0.0  301.389515  1551.747606  49.393557  1.084871
# 4           4    4.0       0.0  299.629962  1551.555272  69.499367  0.976389
#
#      Quality  SN_Ratio  Mean_Intensity
# 0   5.675568  0.549368      478.457364
# 1  19.069794  1.020653      528.937984
# 2  15.219757  1.205106      519.744186
# 3   7.270905  0.789847      487.519380
# 4   6.899343  0.791417      486.733850

# %%
print(int(max(merged['Track_ID'])))
# Out:
# 1478
