# %%
import os
import os.path as op
import boto3
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import skimage.io
import skimage.filters
from skimage.filters import try_all_threshold
from diff_classifier import aws
import matplotlib.image as mpimg
from scipy import ndimage as ndi
from skimage.transform import resize

# %%
s3_folder = '12_11_18_CDllb_microglia_images'
s3_filename = 'contralateral_s1_t0.tif'
s3_bucket = 'mckenna.data'

# %%
s3_folder = '11_16_18_MPT_in_PNNs'
s3_filename = 'HBSS_vid_3_z_stack_MaxIP.tif'
s3_bucket = 'mckenna.data'

# %%
aws.download_s3('{}/{}'.format(s3_folder,s3_filename), s3_filename, bucket_name = s3_bucket)

# %%
img = skimage.io.imread('HBSS_vid_3_z_stack_MaxIP.tif')
img.shape
imgplot = plt.imshow(img[0, :, :], cmap='gray')
plt.show()

# %%
img_scaled = resize(img[0,:,:],(2048,2048))
scaled_plot = plt.imshow(img_scaled, cmap='gray')
plt.show()

# %%
try_all_threshold(img_scaled, figsize=(20,18))
# Out:
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_yen
# (<Figure size 1440x1296 with 8 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x10ee5af28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee76ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11985ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11987a128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11990c240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119924518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11993b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1121fdac8>], dtype=object))

# %%
# This performs threshold without using a preprocessing median filtering technique

thresh = skimage.filters.threshold_otsu(img_scaled)
pnnbinary = img_scaled > thresh
binaryplot = plt.imshow(pnnbinary, cmap='gray')
plt.show()

pnnbinary_filled = ndi.binary_fill_holes(pnnbinary)
binary_filledplot = plt.imshow(pnnbinary_filled, cmap='gray')
plt.show()

# %%
print(img[0,:,:])
print(pnnbinary)
# Out:
# [[105 101 104 ..., 108 111 101]
#  [105 110 105 ..., 107 101 105]
#  [102 103 103 ..., 103 108 108]
#  ...,
#  [104 103 107 ..., 104 103 111]
#  [113 105 111 ..., 104 101 107]
#  [103 103 105 ..., 105 106 108]]
# [[False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  ...,
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]]

# %%
from skimage import morphology

# %%
pnn_clean = morphology.remove_small_objects(pnnbinary_filled, min_size=3000)
pnn_clean_plot = plt.imshow(pnn_clean, cmap='gray')
plt.show()
binary_filledplot = plt.imshow(pnnbinary_filled, cmap='gray')
plt.show()
binaryplot = plt.imshow(pnnbinary, cmap='gray')
plt.show()

# %%
from scipy.ndimage.morphology import distance_transform_edt as Euclidean

euc_img = Euclidean(1-pnn_clean) #1- represents going outwards from the cells
plt.imshow(euc_img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
euc_img
euc_img.min()
# Out:
# 0.0

# %%
import pandas as pd
bucket = 'mckenna.data'
remote_folder = '11_16_18_MPT_in_PNNs'
prefix = 'HBSS_vid_3'
filename = "msd_{}.csv".format(prefix)
aws.download_s3(remote_folder+'/'+filename, filename, bucket_name=bucket)
local_name = filename
merged = pd.read_csv(local_name)

# %%
merged[0:10]
# Out:
#    Unnamed: 0  Frame  Track_ID   X   Y       MSDs     Gauss  Quality  \
# 0           0    0.0       0.0 NaN NaN   0.000000  0.000000      NaN
# 1           1    1.0       0.0 NaN NaN   4.001641  2.396512      NaN
# 2           2    2.0       0.0 NaN NaN   6.834146  1.681477      NaN
# 3           3    3.0       0.0 NaN NaN   7.851303  1.606836      NaN
# 4           4    4.0       0.0 NaN NaN   8.840694  1.439491      NaN
# 5           5    5.0       0.0 NaN NaN  11.364362  1.123226      NaN
# 6           6    6.0       0.0 NaN NaN  12.743154  1.025701      NaN
# 7           7    7.0       0.0 NaN NaN  14.829385  0.891548      NaN
# 8           8    8.0       0.0 NaN NaN  15.837694  0.879375      NaN
# 9           9    9.0       0.0 NaN NaN  16.595764  0.835129      NaN
#
#    SN_Ratio  Mean_Intensity
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4       NaN             NaN
# 5       NaN             NaN
# 6       NaN             NaN
# 7       NaN             NaN
# 8       NaN             NaN
# 9       NaN             NaN

# %%
merged.X.max()
# Out:
# 2047.0

# %%
euc_img.shape
# Out:
# (512, 512)
