# %%
import os
import os.path as op
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import skimage.io
import skimage.filters
from skimage.filters import try_all_threshold
import matplotlib.image as mpimg
from scipy import ndimage as ndi
from skimage.transform import resize
import skimage.morphology
import skimage.feature
import math
from math import sqrt
from skimage.color import rgb2gray
from skimage import measure
from skimage import data, util

# %%
prefix = ['OGD_48h_PI_']
regions = ['corpus_callosum', 'cortex', 'striatum']
images = 5

image_list = []
for pref in prefix:
    for region in regions:
        for num in range(1,images+1):
            image_list.append('{}{}_20x_images_XY{}.tif'.format(pref,region,num))

# %%
image_list
# Out:
# ['OGD_48h_PI_corpus_callosum_20x_images_XY1.tif',
#  'OGD_48h_PI_corpus_callosum_20x_images_XY2.tif',
#  'OGD_48h_PI_corpus_callosum_20x_images_XY3.tif',
#  'OGD_48h_PI_corpus_callosum_20x_images_XY4.tif',
#  'OGD_48h_PI_corpus_callosum_20x_images_XY5.tif',
#  'OGD_48h_PI_cortex_20x_images_XY1.tif',
#  'OGD_48h_PI_cortex_20x_images_XY2.tif',
#  'OGD_48h_PI_cortex_20x_images_XY3.tif',
#  'OGD_48h_PI_cortex_20x_images_XY4.tif',
#  'OGD_48h_PI_cortex_20x_images_XY5.tif',
#  'OGD_48h_PI_striatum_20x_images_XY1.tif',
#  'OGD_48h_PI_striatum_20x_images_XY2.tif',
#  'OGD_48h_PI_striatum_20x_images_XY3.tif',
#  'OGD_48h_PI_striatum_20x_images_XY4.tif',
#  'OGD_48h_PI_striatum_20x_images_XY5.tif']

# %%
output_data = pd.DataFrame(columns=['Image', 'DAPI count','DAPI intensity', 'DAPI area', 'PI count', 'PI intensity', 'PI area', 'PI intensity/DAPI count', 'PI w/in DAPI area', 'PI w/in DAPI/DAPI count', '%overlap PI/DAPI'])

# %%
output_data
# Out:
# Empty DataFrame
# Columns: [Image, DAPI count, DAPI intensity, DAPI area, PI count, PI intensity, PI area, PI intensity/DAPI count, PI w/in DAPI area, PI w/in DAPI/DAPI count, %overlap PI/DAPI]
# Index: []

# %%
for image in image_list:
    img = skimage.io.imread('./c/'+image)
    DAPI = img[0]
    PI = img[1]
    DAPI_filtered = ndi.gaussian_filter(DAPI, sigma=1)
    PI_filtered = ndi.gaussian_filter(PI, sigma=1)
    DAPI_thresh = skimage.filters.threshold_otsu(DAPI_filtered)
    DAPI_binary = DAPI_filtered > DAPI_thresh
    PI_thresh = skimage.filters.threshold_otsu(PI_filtered)
    PI_binary = PI_filtered > PI_thresh
    DAPI_dilation = skimage.morphology.binary_dilation(DAPI_binary)
    DAPI_filled_holes = ndi.binary_fill_holes(DAPI_dilation)
    DAPI_clean = skimage.morphology.remove_small_objects(DAPI_filled_holes, min_size=30)
    PI_dilation = skimage.morphology.binary_dilation(PI_binary)
    PI_filled_holes = ndi.binary_fill_holes(PI_dilation)
    PI_clean = skimage.morphology.remove_small_objects(PI_filled_holes, min_size=30)
    labeled_DAPI, _ = ndi.label(DAPI_clean)
    labeled_PI, _ = ndi.label(PI_clean)
    PI_props = measure.regionprops(labeled_PI)
    DAPI_props = measure.regionprops(labeled_DAPI)
    
    props_DAPI = pd.DataFrame(columns=['centroid x', 'centroid y', 'filled_area', 'area'])

    k = 1
    for props in DAPI_props:
    #Get the properties that I need for areas
    #Add them into a pandas dataframe that has the same number of rows as objects detected
        centroid = props.centroid
        centroid_x = centroid[0]
        centroid_y = centroid[1]
        fill_area = props.filled_area
        area = props.area
        props_DAPI.loc[k] = [centroid_x, centroid_y, fill_area, area]
        k = k + 1
        

    props_PI = pd.DataFrame(columns=['centroid x', 'centroid y', 'filled_area', 'area'])

    j = 1
    for props in PI_props:
    #Get the properties that I need for areas
    #Add them into a pandas dataframe that has the same number of rows as objects detected
        centroid = props.centroid
        centroid_x = centroid[0]
        centroid_y = centroid[1]
        fill_area = props.filled_area
        area = props.area
        props_PI.loc[j] = [centroid_x, centroid_y, fill_area, area]
        j = j + 1
    
    PI_overlap_sum = 0
    DAPI_pixels = 0
    i = 0
    PI_pixels = 0

    for ydim in range(0,512):
        for xdim in range(0,512):
            if labeled_DAPI[ydim][xdim] != 0:
                PI_overlap_sum = PI_overlap_sum + PI[ydim][xdim]
                DAPI_pixels = DAPI_pixels+1
                i = i + 1
                if labeled_PI[ydim][xdim] != 0:
                    PI_pixels = PI_pixels + 1
    
    output_data = output_data.append({'Image':image, 'DAPI count':len(props_DAPI), 'PI count':len(props_PI), 'DAPI intensity':DAPI.sum(), 'PI intensity':PI.sum(), 'DAPI area':props_DAPI['area'].sum(), 'PI area':props_PI['area'].sum(), 'PI intensity/DAPI count':PI.sum()/len(props_DAPI), 'PI w/in DAPI area':PI_overlap_sum, 'PI w/in DAPI/DAPI count':PI_overlap_sum/len(props_DAPI), '%overlap PI/DAPI':PI_pixels/DAPI_pixels}, ignore_index=True)

# %%
output_data
# Out:
#                                             Image DAPI count DAPI intensity  \
# 0   OGD_48h_PI_corpus_callosum_20x_images_XY1.tif        160       47264621
# 1   OGD_48h_PI_corpus_callosum_20x_images_XY2.tif        184       45131220
# 2   OGD_48h_PI_corpus_callosum_20x_images_XY3.tif        185       47504973
# 3   OGD_48h_PI_corpus_callosum_20x_images_XY4.tif        208       49650819
# 4   OGD_48h_PI_corpus_callosum_20x_images_XY5.tif        227       50303203
# 5            OGD_48h_PI_cortex_20x_images_XY1.tif        194       39525872
# 6            OGD_48h_PI_cortex_20x_images_XY2.tif        216       21570956
# 7            OGD_48h_PI_cortex_20x_images_XY3.tif        250       23765194
# 8            OGD_48h_PI_cortex_20x_images_XY4.tif        277       42244458
# 9            OGD_48h_PI_cortex_20x_images_XY5.tif        279       51827393
# 10         OGD_48h_PI_striatum_20x_images_XY1.tif        269       60923329
# 11         OGD_48h_PI_striatum_20x_images_XY2.tif        234       60843988
# 12         OGD_48h_PI_striatum_20x_images_XY3.tif        179       54019899
# 13         OGD_48h_PI_striatum_20x_images_XY4.tif        158       47761819
# 14         OGD_48h_PI_striatum_20x_images_XY5.tif        155       70900924
#
#     DAPI area PI count PI intensity  PI area  PI intensity/DAPI count  \
# 0      8495.0      142      5238704   7931.0             32741.900000
# 1      9266.0      165      5209463   8525.0             28312.298913
# 2     10627.0      171      5274847  10196.0             28512.686486
# 3     14529.0      189      5456635  13955.0             26233.822115
# 4     11407.0      218      5346612  11520.0             23553.356828
# 5     10261.0      208      5063496  11044.0             26100.494845
# 6     11483.0      164      3712039   8402.0             17185.365741
# 7     12788.0      219      4149372  11144.0             16597.488000
# 8     14225.0      248      6189041  12597.0             22343.108303
# 9     14821.0      251      7920952  14165.0             28390.508961
# 10    15634.0      280      6896200  17568.0             25636.431227
# 11    12071.0      220      6547906  12177.0             27982.504274
# 12     9867.0      150      5469858   9007.0             30557.865922
# 13     8840.0      142      5177043   8674.0             32766.094937
# 14    10416.0      148      6036672   9979.0             38946.270968
#
#    PI w/in DAPI area  PI w/in DAPI/DAPI count  %overlap PI/DAPI
# 0             871073              5444.206250          0.811772
# 1             914830              4971.902174          0.805849
# 2             995107              5378.956757          0.838054
# 3            1253359              6025.764423          0.823250
# 4             895680              3945.726872          0.853423
# 5             620017              3195.963918          0.827502
# 6             577594              2674.046296          0.681268
# 7             750631              3002.524000          0.764545
# 8             970917              3505.115523          0.773216
# 9            1078750              3866.487455          0.768707
# 10           1296095              4818.197026          0.885250
# 11            923694              3947.410256          0.816005
# 12            689425              3851.536313          0.793250
# 13            653977              4139.094937          0.816403
# 14            822679              5307.606452          0.819316

# %%
output_data.to_csv('1_25_20_OGD_48h_PI_quantification.csv', encoding='utf-8', index=False)
